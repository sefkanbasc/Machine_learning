# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("C:/Sefkan/polynomial-regression.csv",sep=";")
data
# Out:
#     car_price  car_max_speed
# 0          60            180
# 1          70            180
# 2          80            200
# 3         100            200
# 4         120            200
# 5         150            220
# 6         200            240
# 7         250            240
# 8         300            300
# 9         400            350
# 10        500            350
# 11        750            360
# 12       1000            365
# 13       2000            365
# 14       3000            365

# %%
x = data.car_max_speed.values.reshape(-1,1)
y = data.car_price.values.reshape(-1,1)

plt.scatter(x,y)
plt.xlabel("car_max_speed")
plt.ylabel("car_price")
plt.show()

# %%
from sklearn.linear_model import LinearRegression

linear_model = LinearRegression()
linear_model.fit(x,y)
y_head = linear_model.predict(x)

plt.scatter(x,y)
plt.xlabel("car_max_speed")
plt.ylabel("car_priece")

plt.plot(x,y_head,color="black",label="linear")
plt.show()
print("10 million TL car speed estimation: ",linear_model.predict([[50000]]))
# Out:
# 10 million TL car speed estimation:  [[372020.00198902]]

# %%
from sklearn.preprocessing import PolynomialFeatures
polynomial_regression = PolynomialFeatures(degree=2)

x_polynomial = polynomial_regression.fit_transform(x)

linear_regression2 = LinearRegression()
linear_regression2.fit(x_polynomial,y)

y_head2 = linear_regression2.predict(x_polynomial)
plt.scatter(x,y)
plt.xlabel("car_max_speed")
plt.ylabel("car_priece")
plt.plot(x,y_head,color="red",label="linear")

plt.plot(x,y_head2,color="yellow",label="poly")
plt.legend()
plt.show()

# %%
from sklearn.metrics import r2_score

print("r_square score for linear regression: ", r2_score(y,y_head))
print("r_square score for polynomial regression: ", r2_score(y,y_head2))
# Out:
# r_square score for linear regression:  0.4745823761330056
# r_square score for polynomial regression:  0.5540532844839927

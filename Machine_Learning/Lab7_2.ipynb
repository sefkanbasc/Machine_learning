# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv("C:/Sefkan/Social_Network_Ads.csv")

# %%
x = data.iloc[:, [2, 3]].values
y = data.iloc[:, 4].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 42)

from sklearn.svm import SVC
svc = SVC (random_state=42)
svc.fit(x_train, y_train)
# Out:
# SVC(random_state=42)

# %%
print("Print accuracy of svm algo: {}".format(svc.score(x_test,y_test)))
# Out:
# Print accuracy of svm algo: 0.75

# %%
train_accuracy = []
test_accuracy = []
for i in range(1,100):
    svm = SVC(C=i)
    svm.fit(x_train, y_train)
    train_accuracy.append(svm.score(x_train, y_train))
    test_accuracy.append(svm.score(x_test, y_test))

plt.plot(range(1,100), train_accuracy, label="Training Accuracy")
plt.plot(range(1,100), test_accuracy, label="Test Accuracy")
plt.legend()
plt.xlabel("C values")
plt.ylabel("Accuracy")
plt.grid()
plt.show()
print("Best accuracy is {} when C = {}".format(np.max(test_accuracy), 1+test_accuracy.index(np.max(test_accuracy))))
# Out:
# Best accuracy is 0.76 when C = 14
